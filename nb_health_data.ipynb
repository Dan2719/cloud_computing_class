# %%
# Simple program
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
# A function
def my_function(*kids):
  print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %%
# Arguments and functions
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")

# Another Argument and function example
def my_progrm(ofstudy):
    print(ofstudy + "  InDs")
my_progrm(" ICT Department")
my_progrm(" Doing Data Science")
my_progrm(" In Second Year")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes
#  ICT Department  InDs
#  Doing Data Science  InDs
#  In Second Year  InDs

# %%
# Working with libriaries!
import math
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()
from IPython.display import display, HTML
from patsy import dmatrices
import warnings
warnings.filterwarnings ("ignore")
# %pylab inline
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Populating the interactive namespace from numpy and matplotlib

# %%
nkhatabay_cohort = pd.read_csv(r"C:\Users\Learning\Documents\_MZUNI\LEVEL2\SEM1\INTRO TO CLOUD COMPUTING-BICT2307\GitSkills\Nkhata Bay District Hospital.csv")

# %%
nkhatabay_cohort.shape
# Out:
# (45, 7)

# %%
cohort = pd.DataFrame(nkhatabay_cohort)
cohort
# Out:
#                                                     #      Age group  Gender  \
# 0                                                   1        <1 year  Female
# 1                                                   2      1-4 years  Female
# 2                                                   3      5-9 years  Female
# 3                                                   4    10-14 years  Female
# 4                                                   5    15-19 years  Female
# 5                                                   6    20-24 years  Female
# 6                                                   7    25-29 years  Female
# 7                                                   8    30-34 years  Female
# 8                                                   9    35-39 years  Female
# 9                                                  10    40-44 years  Female
# 10                                                 11    45-49 years  Female
# ...
